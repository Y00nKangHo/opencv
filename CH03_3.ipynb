# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img = cv2.imread('/content/gdrive/MyDrive/디영처/camera.bmp')
img = cv2.imread('/content/gdrive/MyDrive/디영처/aero2.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
cv2_imshow(gImg1)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
#img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/a.bmp')
img = cv2.imread('/content/gdrive/MyDrive/디영처/cat.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg2.shape)
cv2_imshow(gImg2)
# Out:
# (269, 256)
# <PIL.Image.Image image mode=L size=256x269>

# %%
gBit = np.zeros((gImg1.shape[0], gImg1.shape[1]), dtype = np.ubyte)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    #bitVal = gImg1[h, w] & gImg2[h, w]
    #bitVal = gImg1[h, w] | gImg2[h, w]
    bitVal = gImg1[h, w] ^ gImg2[h, w]
    gBit[h, w] = bitVal

cv2_imshow(gBit)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
