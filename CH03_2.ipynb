# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/MyDrive/디영처/고양이 사진.PNG')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg.shape)
plt.imshow(gImg, cmap='gray')
# Out:
# (306, 538)

# %%
gPlus = np.zeros((gImg.shape[0], gImg.shape[1]), dtype=np.ubyte)

# %%
val = 100

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    plusVal = gImg[h,w] + val
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

plt.imshow(gPlus, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/MyDrive/디영처/airplane.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
# Out:
# (210, 320)

# %%
img = cv2.imread('/content/gdrive/MyDrive/디영처/butterfly.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg2.shape)
plt.imshow(gImg2, cmap='gray')
# Out:
# (256, 256)

# %%
import numpy as np

array = np.zeros((256, 256))

value = array[0, 255]

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    plusVal = (np.int32(gImg1[h,w]) + np.int32(gImg2[h,w])) / 2
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

cv2_imshow(gPlus)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-815a9878b69c> in <cell line: 1>()
#       1 for h in range(gImg1.shape[0]):
#       2   for w in range(gImg1.shape[1]):
# ----> 3     plusVal = (np.int32(gImg1[h,w]) + np.int32(gImg2[h,w])) / 2
#       4     if(plusVal > 255):
#       5       plusVal = 255
#
# IndexError: index 256 is out of bounds for axis 1 with size 256

# %%
weight = 0.5

for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    plusVal = np.int32(gImg1[h,w])*weight + np.int32(gImg2[h,w])*(1-weight)
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

cv2_imshow(gPlus)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-5fc962e0b6d9> in <cell line: 3>()
#       3 for h in range(gImg1.shape[0]):
#       4   for w in range(gImg1.shape[1]):
# ----> 5     plusVal = np.int32(gImg1[h,w])*weight + np.int32(gImg2[h,w])*(1-weight)
#       6     if(plusVal > 255):
#       7       plusVal = 255
#
# IndexError: index 256 is out of bounds for axis 1 with size 256
