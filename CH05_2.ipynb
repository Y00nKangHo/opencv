# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/lena256.jpg')
img = cv2.imread('/content/gdrive/MyDrive/디영처/Copy of Target.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # BGR 이미지를 RGB 이미지로 변환

gImg= cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
plt.imshow(gImg,cmap='gray')
# Out:
# (400, 600)

# %%
noiseImg = gImg.copy()

# %%
from random import randint

# %%
# 10% noise
noiseRatio = 10
whiteMax = noiseRatio/2
blackMax = noiseRatio

# %%
noiseImg = gImg.copy()

for h in range(0, gImg.shape[0]):
  for w in range(0, gImg.shape[1]):
    val = randint(0, 100)
    if (val < whiteMax):
      noiseImg[h, w] = 255
    elif (val < blackMax):
      noiseImg[h, w] = 0

cv2_imshow(noiseImg)
# Out:
# <PIL.Image.Image image mode=L size=600x400>

# %%
outImg = cv2.medianBlur(noiseImg, 3)
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=600x400>

# %%
outImg2 = cv2.medianBlur(noiseImg, 5)
cv2_imshow(outImg2)
# Out:
# <PIL.Image.Image image mode=L size=600x400>
