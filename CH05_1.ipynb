# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/MyDrive/디영처/girl.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # BGR 이미지를 RGB 이미지로 변환

gimg= cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
plt.imshow(gimg,cmap='gray')
# Out:
# (256, 256)

# %%
kernel3 = np.ones((3,3),np.float32)/9
kernel5 = np.ones((5,5),np.float32)/25

# %%
outImg3 = cv2.filter2D(gimg,-1,kernel3)
cv2_imshow(outImg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3[0][0] = 1/9
kernel3[0][1] = 1/9
kernel3[0][2] = 1/9
kernel3[1][0] = 1/9
kernel3[1][1] = 1/9
kernel3[1][2] = 1/9
kernel3[2][0] = 1/9
kernel3[2][1] = 1/9
kernel3[2][2] = 1/9

# %%
outImg3 = cv2.filter2D(gimg,-1,kernel3)
cv2_imshow(outImg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
cv2_imshow(outImg5)
outImg3 = cv2.filter2D(gimg,-1,kernel3)
cv2_imshow(outImg3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-df6d6b8cdc18> in <cell line: 1>()
# ----> 1 cv2_imshow(outImg5)
#       2 outImg3 = cv2.filter2D(gimg,-1,kernel3)
#       3 cv2_imshow(outImg3)
#
# NameError: name 'outImg5' is not defined

# %%
outImg5 = cv2.filter2D(gimg,-1,kernel5)
cv2_imshow(outImg5)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg33 = cv2.filter2D(outImg3,-1,kernel3)
cv2_imshow(outImg33)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg333 = cv2.filter2D(outImg33,-1,kernel3)
cv2_imshow(outImg333)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
